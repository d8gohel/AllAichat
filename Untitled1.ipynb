# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    model="llama-3.2-11b-vision-preview",
    api_key="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",
    temperature=0,
)

# %%
response=llm.invoke("is whatsapp good to use")
print(response)
# Out:
# content="WhatsApp is a popular messaging app with over 2 billion users worldwide. Whether it's good to use depends on various factors and personal preferences. Here are some pros and cons to consider:\n\n**Pros:**\n\n1. **Free**: WhatsApp is free to download and use, with no subscription fees or charges for messages, calls, or file sharing.\n2. **Cross-platform compatibility**: WhatsApp is available on multiple platforms, including Android, iOS, Windows Phone, and desktop computers.\n3. **End-to-end encryption**: WhatsApp offers end-to-end encryption, which ensures that only the sender and recipient can read the messages.\n4. **Group chats**: WhatsApp allows group chats with up to 256 people, making it easy to communicate with multiple contacts at once.\n5. **File sharing**: WhatsApp allows users to share files, including photos, videos, documents, and audio files.\n6. **Voice and video calls**: WhatsApp offers free voice and video calls, making it a convenient alternative to traditi
# ...

# %%
# Out:
#   Cell In[12], line 1
#     from  import BaseLoader
#           ^
# SyntaxError: invalid syntax

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 loder= BaseLoader("https://www.google.com")
#       2 print(loder)
#
# NameError: name 'BaseLoader' is not defined

# %%
from langchain_community.document_loaders import WebBaseLoader
loder= WebBaseLoader("https://careers.mastercard.com/us/en/job/R-234888/Senior-Software-Engineer-Asp-net-MVC-entity-framework-angular12-NET-core-CMS-Umbraco")
page_data=loder.load().pop().page_content

# %%
print(page_data)
# Out:
#                    Senior Software Engineer (Asp.net, MVC, entity framework, angular12, .NET core, CMS, Umbraco) in Pune, India, 411006 | R-234888 | Software Engineering Jobs at Mastercard
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# We’re sorry…this specific position is no longer available, but there may be a similar role that is of interest to you.
#
# You may browse all jobs here or explore similar jobs that are available below.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Explore our culture
#
#
#
# We strive to create a culture of decency and belonging. Explore benefits that enable you to grow personally and professionally.
#
#
#
#
#
# ​​​​​​​See what we're made of
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
from langchain_core.prompts import PromptTemplate
prompt_extract =PromptTemplate.from_template("""{url}
give me json of this web with no preamble to apply for job with essensial
""")
chainext= prompt_extract | llm
res= chainext.invoke(input={'url':"https://careers.mastercard.com/us/en/job/R-234888/Senior-Software-Engineer-Asp-net-MVC-entity-framework-angular12-NET-core-CMS-Umbraco"})

# %%
type(res.content)
# Out:
# str

# %%
from langchain_core.output_parsers import JsonOutputParser
jsopnarser= JsonOutputParser()
json_res= jsopnarser.parse()
